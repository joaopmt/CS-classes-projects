# %%
Grupo:
Artur Rodrigues Lima   RA 166916
Joao Pedro Martins     RA 176117
Taylon Luan            RA 177379

# %%
import random
from matplotlib import pyplot as plt

def simulate(n):
    y_axis = []
    population = 3000*[1] + 7000*[0]
    for i in range(1, 2001):
        sample = random.sample(population, k=n)
        prop_A = sum(sample)/len(sample)
        y_axis.append(prop_A)
    plt.figure(num=None, figsize=(12, 6), dpi=80, facecolor='w', edgecolor='k')
    plt.plot(y_axis)
    plt.xlabel('Iteration')
    plt.ylabel('Proportion of votes on candidate A')
    # calculate and print expected value here
    #
    # calculate and print standard deviation here
    #
    
    
simulate(10)
simulate(2000)
